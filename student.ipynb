# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: SHADRACK CHERUIYOT
# * Student pace: DSF-PT02
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
#Importing the necessary extensions
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#studying various Datasets
#"I will examine various datasets in the following codecells below"

# %%
###Dataset 1 - "bom.movie_gross.csv"
df1 = pd.read_csv('bom.movie_gross.csv')
df1_len = str(len(df1))
print("The dataset has " + df1_len + " rows")
print(df1.head())
# Out:
# The dataset has 3387 rows
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
#Dataset 2 - "title.basics.csv"
df2 = pd.read_csv('title.basics.csv')
df2_len = str(len(df2))
print("The dataset has " + df2_len + " rows")
print(df2.head())
# Out:
# The dataset has 146144 rows
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
#Dataset 3 - "tmdb.movies.csv"
df3 = pd.read_csv('tmdb.movies.csv', index_col=0)
df3_len = str(len(df3))
print("The dataset has " + df3_len + " rows")
print(df3.head())
# Out:
# The dataset has 26517 rows
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
#Dataset 4 - "tn.movie_budgets.csv"
df4 = pd.read_csv('tn.movie_budgets.csv', index_col=0)
df4_len = str(len(df4))
print("The dataset has "+ df4_len+ " rows")
df4.head(10)
# Out:
# The dataset has 5782 rows
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# 6   Dec 18, 2015         Star Wars Ep. VII: The Force Awakens
# 7   Apr 27, 2018                       Avengers: Infinity War
# 8   May 24, 2007   Pirates of the Caribbean: At Worldâs End
# 9   Nov 17, 2017                               Justice League
# 10   Nov 6, 2015                                      Spectre
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# 3       $350,000,000    $42,762,350    $149,762,350
# 4       $330,600,000   $459,005,868  $1,403,013,963
# 5       $317,000,000   $620,181,382  $1,316,721,747
# 6       $306,000,000   $936,662,225  $2,053,311,220
# 7       $300,000,000   $678,815,482  $2,048,134,200
# 8       $300,000,000   $309,420,425    $963,420,425
# 9       $300,000,000   $229,024,295    $655,945,209
# 10      $300,000,000   $200,074,175    $879,620,923

# %%
#Dataset 5 - "title.principals.csv"
df5 = pd.read_csv('title.principals.csv')
df5_len = str(len(df5))
print("The dataset has "+ df5_len+ " rows")
df5.head()
# Out:
# The dataset has 1028186 rows
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
#Dataset 6 - "title.akas.csv"
df6 = pd.read_csv('title.akas.csv', index_col=0)
df6 = df6.set_index('ordering')
df6 = df6.sort_index(ascending=False)
df6_len = str(len(df6))
print("The dataset has "+ df6_len+ " rows")
df6.head()
# Out:
# The dataset has 331703 rows
#                                                    title region language  \
# ordering
# 61                       Žvaigždžiu karai: galia nubunda     LT      NaN
# 60                               Star Wars: Güç Uyaniyor     TR       tr
# 59        Star Wars: Episódio VII - O Despertar da Força     PT      NaN
# 58                       Star Wars: O Despertar da Força     BR      NaN
# 57                     Star Wars: Das Erwachen der Macht     DE      NaN
#
#                 types attributes  is_original_title
# ordering
# 61                NaN        NaN                0.0
# 60        imdbDisplay        NaN                0.0
# 59        imdbDisplay        NaN                0.0
# 58        imdbDisplay        NaN                0.0
# 57        alternative        NaN                0.0

# %% [markdown]
# ## In the datasets i have examined above I have gone to the conclusion of using some sample data of the Datasets including;
#         # "tn.movie_budgets.csv" which will help me understand the Financial and Studio data.
#         # "bom.movie_gross.csv" which will help me understand and study the financial data.
#         # "title.basics.csv" which will give me the data to study about genres and movie types/.
#         # "title.akas.csv" which holds the data about the Actors, Directors And the producers of various movies.
# ## In the next cells I will continue to mine on the datasets I have mentioned above so as to learn and study the trends of the data.
# ## I will also compare the data as well as visualize them in plots and graphs so that the infomation i gather becomes easy to interpret and conclude on the insights.

# %% [markdown]
#    ## NB
# ### In the cell below i will deal with the "title.basics.csv" dataset which i imported as **df6** so as to gather information the various genres available in movies.
# ### I will also plot graphs against all the genres to study their relations.

# %%
# Exploring the datset further
df6.tail(20)
# Out:
#                                                 title region language  \
# ordering
# 1                                Love by Prescription     AU      NaN
# 1                                     Pearblossom Hwy     US      NaN
# 1                                    Cartas de Angola     PT      NaN
# 1                                           Dedicated     US      NaN
# 1                               Hobbyhorse Revolution     FI      NaN
# 1                                   Last Men Standing     US      NaN
# 1                             Watch What You Pray For     US      NaN
# 1                                            Marginal     BR      NaN
# 1                                    Two Wheel Cowboy     US      NaN
# 1                             Saheb Biwi Aur Gangster     IN      NaN
# 1                                     Sabates grosses     ES      NaN
# 1                                      I Am a Pervert    XWW       en
# 1                                La peau sur les maux     FR      NaN
# 1                                   The Game: The Doc     US      NaN
# 1                               Bon Appetit, New York     KR      NaN
# 1                                             Mengele     US      NaN
# 1                                       Hikari no oto     JP      NaN
# 1         Once in a Lullaby: PS 22 Chorus Documentary     US      NaN
# 1                                       Trans Bavaria     DE      NaN
# 1               Buenavista (Ang kasaysayan ng Lucena)     PH      NaN
#
#                 types                      attributes  is_original_title
# ordering
# 1                 NaN                             NaN                0.0
# 1                 NaN                             NaN                0.0
# 1                 NaN                             NaN                0.0
# 1                 NaN                             NaN                0.0
# 1                 NaN                             NaN                0.0
# 1                 NaN                             NaN                0.0
# 1                 NaN                             NaN                0.0
# 1                 NaN                             NaN                0.0
# 1                 NaN                             NaN                0.0
# 1                 NaN                             NaN                0.0
# 1                 NaN                             NaN                0.0
# 1                 NaN  informal literal English title                0.0
# 1         imdbDisplay                             NaN                0.0
# 1                 NaN                             NaN                0.0
# 1                 NaN                             NaN                0.0
# 1                 NaN                             NaN                0.0
# 1                 NaN                             NaN                0.0
# 1                 NaN                             NaN                0.0
# 1                 NaN                             NaN                0.0
# 1                 NaN                             NaN                0.0

# %%
df6.head(20)
# Out:
#                                                       title region language  \
# ordering
# 61                          Žvaigždžiu karai: galia nubunda     LT      NaN
# 60                                  Star Wars: Güç Uyaniyor     TR       tr
# 59           Star Wars: Episódio VII - O Despertar da Força     PT      NaN
# 58                          Star Wars: O Despertar da Força     BR      NaN
# 57                        Star Wars: Das Erwachen der Macht     DE      NaN
# 56          Star Wars - Episode VII: Das Erwachen der Macht     DE      NaN
# 55                The Hobbit: The Battle of the Five Armies    XEU       en
# 55                          Star Wars: O Despertar da Força     BR       pt
# 55        Harry Potter y las Reliquias de la Muerte: Par...     CL      NaN
# 54                            Хобит: Битката на петте армии     BG       bg
# 54                               Sutâ wôzu: Fôsu no kakusei     JP      NaN
# 54                    Harry Potter och dödsrelikerna, del 2     FI       sv
# 53                  Der Hobbit: Die Schlacht der fünf Heere     DE      NaN
# 53                                              Зоотрополiс     UA      NaN
# 53                            Star Wars: Than Luc Thuc Tinh     VN      NaN
# 53                 Harry Potter és a Halál ereklyéi 2. rész     HU      NaN
# 53              Pirates of the Caribbean: Salazar's Revenge     EG       en
# 53                        Adeles gyvenimas. I ir II skyrius     LT      NaN
# 52        Harry Potter et les reliques de la mort: 2ème ...     FR      NaN
# 52                                Blue Is the Warmest Color     US      NaN
#
#                 types attributes  is_original_title
# ordering
# 61                NaN        NaN                0.0
# 60        imdbDisplay        NaN                0.0
# 59        imdbDisplay        NaN                0.0
# 58        imdbDisplay        NaN                0.0
# 57        alternative        NaN                0.0
# 56        imdbDisplay        NaN                0.0
# 55        imdbDisplay        NaN                0.0
# 55        imdbDisplay        NaN                0.0
# 55        imdbDisplay        NaN                0.0
# 54                NaN        NaN                0.0
# 54        imdbDisplay        NaN                0.0
# 54        imdbDisplay        NaN                0.0
# 53        imdbDisplay        NaN                0.0
# 53                NaN        NaN                0.0
# 53        imdbDisplay        NaN                0.0
# 53        imdbDisplay        NaN                0.0
# 53        alternative        NaN                0.0
# 53        imdbDisplay        NaN                0.0
# 52        imdbDisplay        NaN                0.0
# 52        imdbDisplay        NaN                0.0

# %% [markdown]
# ### In the cells below, I will filter the data to only retain those necessary for the study success. I will start by grouping the data that are of importance to my study.

# %%
## I will first reset the index from ordering to the default indexing.
df6 = pd.read_csv('title.akas.csv', index_col=0)

# %%
# I will keep the ordering data and the title.
# Since the rest of the columns is not eye-catching to my exploration, I will scrap them off.

necessary_data = df6[['ordering', 'title']]
necessary_data.head()
# Out:
#            ordering                                    title
# title_id
# tt0369610        10                            Джурасик свят
# tt0369610        11                        Jurashikku warudo
# tt0369610        12  Jurassic World: O Mundo dos Dinossauros
# tt0369610        13                  O Mundo dos Dinossauros
# tt0369610        14                           Jurassic World

# %%
# filtering the data that has war in its title
war_df = necessary_data[necessary_data['title'].str.contains("Wars")]
war_df
# Out:
#            ordering                                              title
# title_id
# tt1900924         1                                     Margarine Wars
# tt1568923         1                 Warsaw Ghetto: The Unfinished Film
# tt2094767         1                                        August Wars
# tt2336233         1  David Jones Between the Wars: The Years of Ach...
# tt1739265         1                                               Wars
# ...             ...                                                ...
# tt3923896         1                                          Drug Wars
# tt3010202         1                                         Water Wars
# tt3010202         2                                         Water Wars
# tt4644286         1                   Star Wars Begins: A Filmumentary
# tt7421764         1                 Star Wars: Rise of the First Order
#
# [332 rows x 2 columns]

# %%
## In this cell i wil calculate the mean of the genres ordering with those containing the wars in its title.
## I will also compare the means of the total dataset against the one of those of wars.

### First i will calculate the mean of the movies containing wars in their titles.
wars_df_mean = war_df['ordering'].mean()
print("The ordering mean of war movies are : " + str(wars_df_mean))

### I will then calculate the mean of the overall ordering data below
overal_ordering_mean = df6['ordering'].mean()
print("The overall ordering mean of the overall dataset is : " + str(overal_ordering_mean))
# Out:
# The ordering mean of war movies are : 11.885542168674698
# The overall ordering mean of the overall dataset is : 5.12587163818235

# %%
### i will then plot a bar graph to compare the two means
labels = ["wars_df_mean", "overal_ordering_mean"]
values = [wars_df_mean, overal_ordering_mean]
  
fig = plt.figure(figsize = (8, 8))
 
plt.bar(labels, values, color ='palegreen',
        width = 0.1)
 
plt.xlabel("Means by filter")
plt.ylabel("The mean values of the ordering data")
plt.title("The graph of wars against overal means")
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
plt.pie(values, labels = labels)
plt.show()

# %% [markdown]
# ## In the next cells, I am going to study the "title.principals.csv" to examine the actors and the producers.
# ### I will then plot the graphs to visualize the output of the study to make easy to interpret.

# %%
# running the first 5 rows of the DataFrame
df5.head()
# Out:
#       tconst  ordering     nconst  category       job        characters
# 0  tt0111414         1  nm0246005     actor       NaN       ["The Man"]
# 1  tt0111414         2  nm0398271  director       NaN               NaN
# 2  tt0111414         3  nm3739909  producer  producer               NaN
# 3  tt0323808        10  nm0059247    editor       NaN               NaN
# 4  tt0323808         1  nm3579312   actress       NaN  ["Beth Boothby"]

# %%
## in this cell i will filter the required data so as to have the necessary data i need for the study.

df5_data = df5[['ordering', 'category']]
df5_data
# Out:
#          ordering  category
# 0               1     actor
# 1               2  director
# 2               3  producer
# 3              10    editor
# 4               1   actress
# ...           ...       ...
# 1028181         1     actor
# 1028182         2      self
# 1028183         3  director
# 1028184         4    writer
# 1028185         5  producer
#
# [1028186 rows x 2 columns]

# %%
## In this cell i will find out the different types of categories of the movie participants
category_types = df5_data['category'].unique()
category_types
# Out:
# array(['actor', 'director', 'producer', 'editor', 'actress', 'composer',
#        'cinematographer', 'writer', 'self', 'production_designer',
#        'archive_footage', 'archive_sound'], dtype=object)

# %%
## In this cell i wikll convert the "DF5_DATA" to sql so as to be easy to manipulate

import sqlite3

conn = sqlite3.connect('df5_sql')
cur = conn.cursor()

cur.execute('CREATE TABLE IF NOT EXISTS necessary (ordering number, category text)')
conn.commit()


df5_data.to_sql('necessary', conn, if_exists='replace', index = False)
# Out:
# 1028186

# %%
## writing a querry to group the data

q = ("""
SELECT *
FROM necessary
WHERE ordering == 1
ORDER BY ordering ASC
"""
)

pd.read_sql(q, conn)
# Out:
#         ordering category
# 0              1    actor
# 1              1  actress
# 2              1    actor
# 3              1  actress
# 4              1    actor
# ...          ...      ...
# 143449         1    actor
# 143450         1  actress
# 143451         1    actor
# 143452         1    actor
# 143453         1    actor
#
# [143454 rows x 2 columns]

# %%
grouped = ("""
SELECT *
FROM necessary
GROUP BY category
ORDER BY ordering DESC

""")

pd.read_sql(grouped, conn)
# Out:
#     ordering             category
# 0         10  production_designer
# 1         10               editor
# 2          9      cinematographer
# 3          8             composer
# 4          6               writer
# 5          4        archive_sound
# 6          3             producer
# 7          2             director
# 8          1                 self
# 9          1      archive_footage
# 10         1              actress
# 11         1                actor

# %%
nec_data = pd.read_sql(grouped, conn)
nec_data.plot.bar(x="category", y="ordering", rot=70, title="Distribution of 'ordering' against the participants 'category'");

# %%
import seaborn as sns
sns.barplot(x = 'category', y = 'ordering', data = nec_data)
plt.xticks(rotation = 70)
plt.title("Distribution of 'ordering' against the participants 'category'")
plt.show()

# %%
plt.scatter(nec_data['category'], nec_data['ordering'], c ="blue")


plt.title("Scatter plot mean orderings")
plt.xlabel("category")
plt.ylabel("ordering")
plt.xticks(rotation = 70)

# To show the plot
plt.show()

# %% [markdown]
# # In the cells above, i have studied the "tile.principals.csv" and found out that the most ordering is based on the production designer and editor.
# I also ploted a bar graph to visualize my findings.
#
# ### In the following cells, I am going to further study the "tn.movie_budgets.csv" so as to draw a meaningfull conclusion on the financials.

# %%
## First i am going to execute the head of the DataFrame so as to take a reminder look on the data it contains

df4.head()
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# 3       $350,000,000    $42,762,350    $149,762,350
# 4       $330,600,000   $459,005,868  $1,403,013,963
# 5       $317,000,000   $620,181,382  $1,316,721,747

# %%
df4['release_date']
# Out:
# id
# 1     Dec 18, 2009
# 2     May 20, 2011
# 3      Jun 7, 2019
# 4      May 1, 2015
# 5     Dec 15, 2017
#           ...
# 78    Dec 31, 2018
# 79     Apr 2, 1999
# 80    Jul 13, 2005
# 81    Sep 29, 2015
# 82     Aug 5, 2005
# Name: release_date, Length: 5782, dtype: object

# %%
## sorted dataframe of the first 10 .

selected_sorted_df4 = df4.head()
selected_sorted_df4
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# 3       $350,000,000    $42,762,350    $149,762,350
# 4       $330,600,000   $459,005,868  $1,403,013,963
# 5       $317,000,000   $620,181,382  $1,316,721,747

# %%
ddf4 = df4[['movie', 'production_budget', 'domestic_gross', 'worldwide_gross']].head()
ddf4
# Out:
#                                           movie production_budget  \
# id
# 1                                        Avatar      $425,000,000
# 2   Pirates of the Caribbean: On Stranger Tides      $410,600,000
# 3                                  Dark Phoenix      $350,000,000
# 4                       Avengers: Age of Ultron      $330,600,000
# 5             Star Wars Ep. VIII: The Last Jedi      $317,000,000
#
#    domestic_gross worldwide_gross
# id
# 1    $760,507,625  $2,776,345,279
# 2    $241,063,875  $1,045,663,875
# 3     $42,762,350    $149,762,350
# 4    $459,005,868  $1,403,013,963
# 5    $620,181,382  $1,316,721,747

# %%
## I will then continue to study the "df1" data and examine to visualize it.
df1.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
## i will then filter the necessary data for my study

df1_nec = df1[['year', 'studio', 'domestic_gross', 'foreign_gross']].dropna()
df1_nec
# Out:
#       year        studio  domestic_gross foreign_gross
# 0     2010            BV     415000000.0     652000000
# 1     2010            BV     334200000.0     691300000
# 2     2010            WB     296000000.0     664300000
# 3     2010            WB     292600000.0     535700000
# 4     2010          P/DW     238700000.0     513900000
# ...    ...           ...             ...           ...
# 3275  2018           LGF          1400.0       1500000
# 3286  2018           IFC        725000.0        229000
# 3309  2018    Grindstone         10000.0        256000
# 3342  2018  Darin Southa         93200.0          5200
# 3353  2018            FM         43200.0         30000
#
# [2007 rows x 4 columns]

# %%
df1_nec_sort = df1_nec.sort_values(by = ['foreign_gross', 'domestic_gross'], ascending=False).head(10)
df1_nec_sort
# Out:
#       year     studio  domestic_gross foreign_gross
# 1331  2013       FoxS       2300000.0         99700
# 1805  2014      Magn.          3500.0         99700
# 1546  2014       TriS      91400000.0       9900000
# 3181  2018       Sony      30600000.0       9900000
# 155   2010         3D       6100000.0       9900000
# 2906  2017       FoxS       3900000.0       9900000
# 3225  2018  Greenwich       1600000.0       9900000
# 1291  2013       RTWC        779000.0       9900000
# 510   2011       Jan.        612000.0       9900000
# 2100  2015        FCW        351000.0        988000

# %%
df1_nec_sort['foreign_gross'] = df1_nec_sort['foreign_gross'].astype(int)
df1_nec_sort['domestic_gross'] = df1_nec_sort['domestic_gross'].astype(int)

# %%
## plot a comparison graph to study the trend in the gross earnings

data1 = pd.DataFrame(df1_nec_sort);
index = data1['studio']

data1.index = index;

 

data1.plot.bar(rot=20, title="Comparison of the different gross earnings per studio");

plt.show(block=True);

# %%
## I will plot a scatter plot to visualize the above data for more interpretability
plt.scatter(index, data1['domestic_gross'], c ="blue")
plt.scatter(index, data1['foreign_gross'], c ="red")

plt.title("Scatter plot")
plt.xlabel("studio")
plt.ylabel("gross earnings")

# To show the plot
plt.show()

# %% [markdown]
# ## In the cell above the visualizations shows that the Tris studio brings alot of gross incomes through the movies it produces.
#     It therefore depicts that Tris studio movies are the most likely to generate more income since the studio    movies are most loved.
